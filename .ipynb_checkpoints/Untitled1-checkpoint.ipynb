# %%
from datetime import datetime
import numpy as np
import pandas as pd
import seaborn as sns
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import matplotlib.pylab as plt
# %matplotlib inline
from pmdarima.arima import auto_arima
from statsmodels.tsa.stattools import adfuller, acf, pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 10,6

# %%
path = 'data.csv'
data = pd.read_csv(path)

# %%
data['Date'] = pd.to_datetime(data['Date'])
data['Month'] = pd.to_datetime(data['Date']).dt.to_period('M')

# %%
data
# Out:
#            Date       State Region       Category     Sales  Quantity    Month
# 0    2016-11-08    Kentucky  South        Laptops    261.96       2.0  2016-11
# 1    2016-11-08    Kentucky  South        Laptops    731.94       3.0  2016-11
# 2    2016-06-12  California   West  Mobile Phones     14.62       2.0  2016-06
# 3    2019-10-11     Florida  South        Laptops  957.5775       5.0  2019-10
# 4    2019-10-11     Florida  South  Mobile Phones    22.368       2.0  2019-10
# ...         ...         ...    ...            ...       ...       ...      ...
# 9989 2018-01-21     Florida  South        Laptops    25.248       3.0  2018-01
# 9990 2017-02-26  California   West        Laptops     91.96       2.0  2017-02
# 9991 2017-02-26  California   West       Cameras    258.576       2.0  2017-02
# 9992 2017-02-26  California   West  Mobile Phones      29.6       4.0  2017-02
# 9993 2017-05-04  California   West  Mobile Phones    243.16       2.0  2017-05
#
# [9994 rows x 7 columns]

# %%
data_month = data[['Month','Sales']]

# %%
data_month = data.groupby(['Month'], as_index = False).sum().sort_values('Month', ascending = True)

# %%
data_month
# Out:
#       Month  Quantity
# 0   2016-01   358.000
# 1   2016-02   306.000
# 2   2016-03   579.000
# 3   2016-04  1323.704
# 4   2016-05   863.000
# 5   2016-06   742.000
# 6   2016-07   758.000
# 7   2016-08   693.000
# 8   2016-09  1316.000
# 9   2016-10   767.000
# 10  2016-11  1406.000
# 11  2016-12  1414.000
# 12  2017-01   597.000
# 13  2017-02   363.000
# 14  2017-03   885.000
# 15  2017-04   733.000
# 16  2017-05  1288.744
# 17  2017-06   931.000
# 18  2017-07   840.000
# 19  2017-08   884.000
# 20  2017-09  1947.960
# 21  2017-10  1133.000
# 22  2017-11  1840.000
# 23  2017-12  1723.000
# 24  2018-01   284.000
# 25  2018-02   159.000
# 26  2018-03   585.000
# 27  2018-04   650.784
# 28  2018-05   466.000
# 29  2018-06   521.000
# 30  2018-07   550.000
# 31  2018-08   609.000
# 32  2018-09  1000.000
# 33  2018-10   573.000
# 34  2018-11  1219.000
# 35  2018-12  1480.744
# 36  2019-01   236.000
# 37  2019-02   239.000
# 38  2019-03   515.000
# 39  2019-04   543.000
# 40  2019-05   575.000
# 41  2019-06   486.000
# 42  2019-07   557.000
# 43  2019-08   598.000
# 44  2019-09  1086.000
# 45  2019-10   631.000
# 46  2019-11  1310.000
# 47  2019-12  1203.000

# %%
data_month.plot(x='Month', y='Sales')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
#Perform Augmented Dickey–Fuller test:
print('Results of Dickey Fuller Test:')
dftest = adfuller(data_month['Sales'], autolag='AIC')

dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
    
print(dfoutput)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                 -4.637303
# p-value                         0.000110
# #Lags Used                      0.000000
# Number of Observations Used    47.000000
# Critical Value (1%)            -3.577848
# Critical Value (5%)            -2.925338
# Critical Value (10%)           -2.600774
# dtype: float64

# %%
#Chia train test

# %%
# train_start, train_end = '2016-01', '2019-05'
# test_start, test_end = '2019-06', '2019-12'
# train_month = data_month[train_start:train_end]["Sales"].dropna()
# test_month = data_month['Sales'][test_start:test_end].dropna()
train_month = data_month['Sales'][:-7]
test_month = data_month['Sales'][-7:]

# %%
test_month
# Out:
# 41    24797.2920
# 42    28765.3250
# 43    36898.3322
# 44    64595.9180
# 45    31404.9235
# 46    75972.5635
# 47    74919.5212
# Name: Sales, dtype: float64

# %%
# Model

# %%
model_sarima_month = auto_arima(train_month, start_p=0, start_q=0,
                               max_p=7, max_q=7, m=12,
                               start_P=0, seasonal = True,
                               d=0, D=0, trace=True,
                               error_action='ignore',
                               suppress_warmings=True,
                               stepwise=True)
print(model_sarima_month.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : AIC=944.072, Time=1.16 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=952.494, Time=0.07 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=942.862, Time=0.72 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=941.952, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=1012.184, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=948.629, Time=0.05 sec
#  ARIMA(0,0,1)(1,0,1)[12] intercept   : AIC=943.882, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,2)[12] intercept   : AIC=941.736, Time=0.22 sec
#  ARIMA(0,0,1)(1,0,2)[12] intercept   : AIC=943.729, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,2)[12] intercept   : AIC=944.052, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,2)[12] intercept   : AIC=942.667, Time=0.09 sec
#  ARIMA(0,0,2)(0,0,2)[12] intercept   : AIC=943.990, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,2)[12] intercept   : AIC=939.775, Time=0.07 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=940.340, Time=0.04 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=941.735, Time=0.12 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=941.775, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,2)[12] intercept   : AIC=942.158, Time=0.12 sec
#  ARIMA(2,0,1)(0,0,2)[12] intercept   : AIC=944.500, Time=0.15 sec
#  ARIMA(1,0,0)(0,0,2)[12]             : AIC=950.186, Time=0.08 sec
#
# Best model:  ARIMA(1,0,0)(0,0,2)[12] intercept
# Total fit time: 3.301 seconds
# 939.7753169892056

# %%
model_sarima_month.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                       y   No. Observations:                   41
# Model:             SARIMAX(1, 0, 0)x(0, 0, [1, 2], 12)   Log Likelihood                -464.888
# Date:                                 Fri, 28 May 2021   AIC                            939.775
# Time:                                         00:21:40   BIC                            948.343
# Sample:                                              0   HQIC                           942.895
#                                                   - 41
# Covariance Type:                                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   3.134e+04   1.72e+04      1.825      0.068   -2324.313     6.5e+04
# ar.L1          0.3402      0.304      1.120      0.263      -0.255       0.936
# ma.S.L12       0.4932      0.383      1.287      0.198      -0.258       1.244
# ma.S.L24       0.3336      0.538      0.621      0.535      -0.720       1.387
# sigma2      5.628e+08      0.077   7.35e+09      0.000    5.63e+08    5.63e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.28   Jarque-Bera (JB):                 1.39
# Prob(Q):                              0.60   Prob(JB):                         0.50
# Heteroskedasticity (H):               0.79   Skew:                             0.45
# Prob(H) (two-sided):                  0.66   Kurtosis:                         2.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 7.55e+26. Standard errors may be unstable.
# """

# %%
model_sarima_month.plot_diagnostics(figsize=(15,12))
plt.show()

# %%
fig,ax= plt.subplots(2,1, figsize=(10,5))
fig=sm.tsa.graphics.plot_acf(train_month, lags=20, ax=ax[0])
fig=sm.tsa.graphics.plot_pacf(train_month, lags=19, ax=ax[1])
plt.show()

# %%
n_pred = 7
fitted_month, confint_month = model_sarima_month.predict(n_periods=n_pred, return_conf_int=True)

# %%
# date = pd.date_range(train_month.index[-1], periods=n_pred, freq='MS')

# %%
date = pd.date_range(start='06/01/2019',end='31/12/2019', freq='MS')

# %%
date
# Out:
# DatetimeIndex(['2019-06-01', '2019-07-01', '2019-08-01', '2019-09-01',
#                '2019-10-01', '2019-11-01', '2019-12-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
date_train = pd.date_range(start='01/01/2016', end='31/12/2019', freq='MS')

# %%
data_month2 = data_month.loc[:,'Sales']
data_month2 = data_month2.values

# %%
data_month2
# Out:
# array([ 18542.491 ,  22978.815 ,  51715.875 ,  38750.039 ,  56987.728 ,
#         40344.534 ,  39261.963 ,  31115.3743,  73410.0249,  59687.745 ,
#         79411.9658,  96999.043 ,  43971.374 ,  20301.1334,  58872.3528,
#         36521.5361,  44261.1102,  52981.7257,  45264.416 ,  63120.888 ,
#         87866.652 ,  77776.9232, 118447.825 ,  83829.3188,  14236.895 ,
#          4519.892 ,  55691.009 ,  28295.345 ,  23648.287 ,  34595.1276,
#         33946.393 ,  27909.4685,  81777.3508,  31453.393 ,  78628.7167,
#         69545.6205,  18174.0756,  11951.411 ,  38726.252 ,  34195.2085,
#         30131.6865,  24797.292 ,  28765.325 ,  36898.3322,  64595.918 ,
#         31404.9235,  75972.5635,  74919.5212])

# %%
fitted_seri_month = pd.Series(fitted_month, index=date)
data_month3 = pd.Series(data_month2, index=date_train)

# %%
lower = confint_month[:, 0]
upper = confint_month[:, 1]

plt.figure(figsize = (12,6))
plt.plot(data_month3, label = 'Actual')
plt.plot(fitted_seri_month, color='red', linestyle='--', label = 'Forecast')
plt.fill_between(date, lower, upper, color = 'grey', alpha=0.2)
plt.legend()
plt.title('SARIMA forecast')
plt.show()
